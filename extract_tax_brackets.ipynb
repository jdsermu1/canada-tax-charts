# %%
import pandas as pd

# %%
f = pd.read_csv("data/11100054.csv", sep=";")

# %%
f.head()
# Out:
#    PÉRIODE DE RÉFÉRENCE     GÉO           DGUID Percentiles du revenu  \
# 0                  1992  Canada  2016A000011124   Tous les déclarants
# 1                  1992  Canada  2016A000011124   Tous les déclarants
# 2                  1992  Canada  2016A000011124   Tous les déclarants
# 3                  1992  Canada  2016A000011124   Tous les déclarants
# 4                  1992  Canada  2016A000011124   Tous les déclarants
#
#             Groupe d'âge                       Type d'impôt et de transfert  \
# 0  Total, 18 ans et plus  Impôt fédéral et provincial sur les revenus et...
# 1  Total, 18 ans et plus  Impôt fédéral et provincial sur les revenus et...
# 2  Total, 18 ans et plus  Impôt fédéral et provincial sur les revenus et...
# 3  Total, 18 ans et plus  Impôt fédéral et provincial sur les revenus et...
# 4  Total, 18 ans et plus  Impôt fédéral et provincial sur les revenus et...
#
#                      Statistiques UNITÉ DE MESURE  \
# ...

# %%
f.loc[(f["PÉRIODE DE RÉFÉRENCE"]==2021)].head(
)
# Out:
#          PÉRIODE DE RÉFÉRENCE     GÉO           DGUID Percentiles du revenu  \
# 6357120                  2021  Canada  2016A000011124   Tous les déclarants
# 6357121                  2021  Canada  2016A000011124   Tous les déclarants
# 6357122                  2021  Canada  2016A000011124   Tous les déclarants
# 6357123                  2021  Canada  2016A000011124   Tous les déclarants
# 6357124                  2021  Canada  2016A000011124   Tous les déclarants
#
#                   Groupe d'âge  \
# 6357120  Total, 18 ans et plus
# 6357121  Total, 18 ans et plus
# 6357122  Total, 18 ans et plus
# 6357123  Total, 18 ans et plus
# 6357124  Total, 18 ans et plus
#
#                               Type d'impôt et de transfert  \
# 6357120  Impôt fédéral et provincial sur les revenus et...
# 6357121  Impôt fédéral et provincial sur les revenus et...
# 6357122  Impôt fédéral et provincial sur les revenus et...
# 6357123  Impôt fédéral et provincial sur les revenus et...
# ...

# %%
d = pd.read_csv("data/11100054_MetaData.csv", sep=";")

# %%
d.head(
)
# Out:
#                                                             Titre du cube  \
# Taux d'imposition effectifs individuels fédérau...               11100054
# Numéro d'identification de la dimension               Nom de la dimension
# 1                                                              Géographie
# 2                                                   Percentiles du revenu
# 3                                                            Groupe d'âge
#
#                                                    Numéro d'identification du produit  \
# Taux d'imposition effectifs individuels fédérau...                                NaN
# Numéro d'identification de la dimension                        Notes sur la dimension
# 1                                                                                 NaN
# 2                                                                                   9
# 3                                                                                 NaN
#
# ...
